# %%
import pandas as pd
import numpy as np
import time
import requests
import bs4
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

# %%
def get_pnd_dataframe():
    url = "https://pad.skyozora.com/pets/statistics/"
    r = requests.get(url, timeout=20).text
    soup = BeautifulSoup(r, "html.parser")

    pnd = []
    table = soup.find_all(name="table")[3]
    for i in range(20):
        trs = table.find_all(name="tr")[i+1]
        tds = trs.find_all(name="td")

        pet_name = tds[1].find(name="a").get("title")
        pet_name = pet_name.split("- ")[1]

        link = tds[1].find(name="a").get("href")
        link = "https://pad.skyozora.com/" + link

        review = tds[2].find_all(text=True)
        review = "".join(review)

        pnd.append([i+1, pet_name, link, review])
        
    df = pd.DataFrame(pnd)
    df.columns = ["rank", "pet_name", "link", "review"]
    
    return df

# %%
df = get_pnd_dataframe()
df
# Out:
#     rank           pet_name                                link   review
# 0      1               平子真子  https://pad.skyozora.com/pets/6097    10/10
# 1      2         聖燈之炎天使・烏列爾  https://pad.skyozora.com/pets/5774  9.96/10
# 2      3         靜淑之吹龍樂士・浮奈  https://pad.skyozora.com/pets/5337  9.92/10
# 3      4         白羽騎士 布拉達曼特  https://pad.skyozora.com/pets/5521  9.91/10
# 4      5          海馬瀬人＆藍眼白龍  https://pad.skyozora.com/pets/5784   9.9/10
# 5      6           孤峰之新娘・澤娜  https://pad.skyozora.com/pets/5382   9.9/10
# 6      7        烈空之紅龍喚士・索妮亞  https://pad.skyozora.com/pets/5533  9.89/10
# 7      8             超新龍・小龍  https://pad.skyozora.com/pets/5316  9.88/10
# 8      9        庇護之巫女神・奇稻田姫  https://pad.skyozora.com/pets/2280  9.82/10
# 9     10          初雪之大魔女・莉邪  https://pad.skyozora.com/pets/5849   9.8/10
# 10    11          聖堂的女主神・迦梨  https://pad.skyozora.com/pets/2511  9.79/10
# 11    12           轉生金剛夜叉明王  https://pad.skyozora.com/pets/5324  9.78/10
# 12    13                間桐櫻  https://pad.skyozora.com/pets/5019  9.77/10
# 13    14         浮雲之鬼龍契士・須王  https://pad.skyozora.com/pets/4797  9.77/10
# 14    15             轉生亞斯她錄  https://pad.skyozora.com/pets/3507  9.76/10
# 15    16             超轉生芙蕾雅  https://pad.skyozora.com/pets/5857  9.74/10
# 16    17  闇馬利克＆太陽神的翼神龍-不死鳥-  https://pad.skyozora.com/pets/5788  9.72/10
# 17    18       清心之管龍樂士・瑪莉艾兒  https://pad.skyozora.com/pets/5335   9.7/10
# 18    19               轉生亞蒙  https://pad.skyozora.com/pets/4267   9.7/10
# 19    20             轉生安朵美達  https://pad.skyozora.com/pets/4275   9.7/10
